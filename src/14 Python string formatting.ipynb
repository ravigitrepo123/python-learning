# %% [markdown]
# F-String was introduced in Python 3.6, and is now the preferred way of formatting strings.
#
# Before Python 3.6 we had to use the **format()** method.

# %% [markdown]
# ### ## **F-Strings**
# F-string allows you to format selected parts of a string.
#
# To specify a string as an f-string, simply put an f in front of the string literal, like this:

# %%
txt = f"clever studies classes"
print(txt)
# Out:
# clever studies classes

# %% [markdown]
# ###Placeholders and Modifiers
# To format values in an f-string, add placeholders {}, a placeholder can contain variables, operations, functions, and modifiers to format the value.

# %%
num = 20
txt = f"the no.of rows in a table is {num}"
print(txt)
# Out:
# the no.of rows in a table is 20

# %% [markdown]
# A placeholder can also include a modifier to format the value.
#
# A modifier is included by adding a colon : followed by a legal formatting type, like .2f which means fixed point number with 2 decimals

# %%
#Display the num with 2 decimals:
num = 20
txt = f"the no.of rows in a table is {num:.2f}"
print(txt)
# Out:
# the no.of rows in a table is 20.00

# %%
#You can also format a value directly without keeping it in a variable:
txt = f"the no.of rows in a table is {20:.2f}"
print(txt)
# Out:
# the no.of rows in a table is 20.00

# %% [markdown]
# ###Perform Operations in F-Strings
# You can perform Python operations inside the placeholders.
#
# You can do math operations:

# %%
#Perform a math operation in the placeholder, and return the result:
txt = f"the no.of rows in a table is {20 + 2} "
print(txt)
# Out:
# the no.of rows in a table is 22

# %% [markdown]
# You can perform if...else statements inside the placeholders:

# %%
num = 44
txt = f"the no of rows are  {'greater' if num>44 else 'lesser'}"
print(txt)
# Out:
# the no of rows are  lesser

# %% [markdown]
# ###Execute Functions in F-Strings
# You can execute functions inside the placeholder:

# %%
#Use the string method upper()to convert a value into upper case letters:
a = "clever studies"
txt = f"I love {a.upper()}"
print(txt)
# Out:
# I love CLEVER STUDIES

# %% [markdown]
# The function does not have to be a built-in Python method, you can create your own functions and use them:

# %%
#Create a function that converts feet into meters:
def myconverter(x):
  return x * 0.3048

txt = f"The plane is flying at a {myconverter(30000)} meter altitude"
print(txt)
# Out:
# The plane is flying at a 9144.0 meter altitude

# %% [markdown]
# ###More Modifiers
# There are several other modifiers that can be used to format values:

# %%
#Use a comma as a thousand separator:
num = 59000
txt = f"The no of rows is {num:,}"
print(txt)
# Out:
# The no of rows is 59,000

# %%
##To demonstrate, we insert the number 8 to set the available space for the value to 8 characters
##Use "<" to left-align the value:
txt = f"clever studies {49:<8} classes"
print(txt)
# Out:
# clever studies 49       classes

# %%
##Use ">" to right-align the value:
txt = f"clever studies {49:>8} classes"
print(txt)
# Out:
# clever studies       49 classes

# %%
###Use "^" to center-align the value:
txt = f"clever studies {49:^8} classes"
print(txt)
# Out:
# clever studies    49    classes

# %%
#Use "=" to place the plus/minus sign at the left most position:
txt = f"clever studies {-49:=8} classes"
print(txt)
# Out:
# clever studies -     49 classes

# %%
#Use "+" to always indicate if the number is positive or negative:
txt = f"clever studies {-49:+} and {53:+} classes"
print(txt)
# Out:
# clever studies -49 and +53 classes

# %%
##Use "-" to always indicate if the number is negative (positive numbers are displayed without any sign):
txt = f"clever studies {-49:-} and {53:-} classes"
print(txt)
# Out:
# clever studies -49 and 53 classes

# %%
#Use "," to add a comma as a thousand separator:
txt = f"The total no of rows count is {13800000000:,}"
print(txt)
# Out:
# The total no of rows count is 13,800,000,000

# %%
#Use a underscore as a thousand separator:
txt = f"The total no of rows count is {13800000000:_}"
print(txt)
# Out:
# The total no of rows count is 13_800_000_000

# %%
#Use "b" to convert the number into binary format:
txt = f"The binary version of 5 is {5:b}"
print(txt)
# Out:
# The binary version of 5 is 101

# %%
#Use "d" to convert a number, in this case a binary number, into decimal number format:
txt = f"We have {0b101:d} chickens."
print(txt)
# Out:
# We have 5 chickens.

# %%
#Use "e" to convert a number into scientific number format (with a lower-case e):
txt = f"We have {5:e} chickens."
print(txt)
# Out:
# We have 5.000000e+00 chickens.

# %%
#Use "E" to convert a number into scientific number format (with an upper-case E):
txt = f"We have {5:E} chickens."
print(txt)
# Out:
# We have 5.000000E+00 chickens.

# %%
#Use "f" to convert a number into a fixed point number, default with 6 decimals, but use a period followed by a number to specify the number of decimals:
txt = f"The price is {45:.2f} dollars."
print(txt)
#without the ".2" inside the placeholder, this number will be displayed like this:
txt = f"The price is {45:f} dollars."
print(txt)
# Out:
# The price is 45.00 dollars.
# The price is 45.000000 dollars.

# %%
#Use "F" to convert a number into a fixed point number, but display inf and nan as INF and NAN:
x = float('inf')
txt = f"The price is {x:F} dollars."
print(txt)
#same example, but with a lower case f:
txt = f"The price is {x:f} dollars."
print(txt)
# Out:
# The price is INF dollars.
# The price is inf dollars.

# %%
#Use "o" to convert the number into octal format:
txt = f"The octal version of 10 is {10:o}"
print(txt)
# Out:
# The octal version of 10 is 12

# %%
#Use "x" to convert the number into Hex format:
txt = f"The Hexadecimal version of 255 is {255:x}"
print(txt)
# Out:
# The Hexadecimal version of 255 is ff

# %%
#Use "X" to convert the number into upper-case Hex format:
txt = f"The Hexadecimal version of 255 is {255:X}"
print(txt)
# Out:
# The Hexadecimal version of 255 is FF

# %%
#Use "%" to convert the number into a percentage format:
txt = f"You scored {0.25:%}"
print(txt)
#Or, without any decimals:
txt = f"You scored {0.25:.0%}"
print(txt)
# Out:
# You scored 25.000000%
# You scored 25%

# %% [markdown]
# ###String format()
# Before Python 3.6 we used the format() method to format strings.
# The format() method can still be used, but f-strings are faster and the preferred way to format strings.
# The next examples in this page demonstrates how to format strings with the format() method.
# The format() method also uses curly brackets as placeholders {}, but the syntax is slightly different:

# %%
#Add a placeholder where you want to display the num:
num = 67
txt = "The no of rows count is {}"
print(txt.format(num))
# Out:
# The no of rows count is 67

# %%
#And add more placeholders:
quantity = 3
itemno = 567
price = 49
myorder = "I want {} pieces of item number {} for {:.2f} dollars."
print(myorder.format(quantity, itemno, price))
# Out:
# I want 3 pieces of item number 567 for 49.00 dollars.

# %% [markdown]
# ###Index Numbers
# You can use index numbers (a number inside the curly brackets {0}) to be sure the values are placed in the correct placeholders:

# %%
quantity = 3
itemno = 567
price = 49
myorder = "I want {0} pieces of item number {1} for {2:.2f} dollars."
print(myorder.format(quantity, itemno, price))
# Out:
# I want 3 pieces of item number 567 for 49.00 dollars.

# %%
#Also, if you want to refer to the same value more than once, use the index number:
age = 36
name = "John"
txt = "His name is {1}. {1} is {0} years old."
print(txt.format(age, name))
# Out:
# His name is John. John is 36 years old.

# %% [markdown]
# ####Named Indexes
# You can also use named indexes by entering a name inside the curly brackets {carname}, but then you must use names when you pass the parameter values txt.format(carname = "Ford"):

# %%
myorder = "I have a {carname}, it is a {model}."
print(myorder.format(carname = "Ford", model = "Mustang"))
# Out:
# I have a Ford, it is a Mustang.
