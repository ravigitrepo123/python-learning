# %% [markdown]
# ####Tuple
# Tuples are used to store multiple items in a single variable.
#
# Tuple is one of 4 built-in data types in Python used to store collections of data

# %%
tuple1 = ("clever", "studies", "classes")
print(tuple1)
# Out:
# ('clever', 'studies', 'classes')

# %% [markdown]
# ####Tuple Items
# Tuple items are ordered, unchangeable, and allow duplicate values.
#
# Tuple items are indexed, the first item has index [0], the second item has index [1] etc.

# %% [markdown]
# ####Ordered
# When we say that tuples are ordered, it means that the items have a defined order, and that order will not change.

# %% [markdown]
# ####Unchangeable
# Tuples are unchangeable, meaning that we cannot change, add or remove items after the tuple has been created.

# %% [markdown]
# ####Allow Duplicates
# Since tuples are indexed, they can have items with the same value:

# %%
tuple1 = ("clever", "studies", "classes", "are", "classes","going on")
print(tuple1)
# Out:
# ('clever', 'studies', 'classes', 'are', 'classes', 'going on')

# %% [markdown]
# ####Tuple Length
# To determine how many items a tuple has, use the len() function:

# %%
tuple1 = ("clever", "studies", "classes", "are", "going on")
print(len(tuple1))
# Out:
# 5

# %% [markdown]
# ####Create Tuple With One Item
# To create a tuple with only one item, you have to add a comma after the item, otherwise Python will not recognize it as a tuple

# %%
tuple1 = ("clever",)
print(type(tuple1))
# Out:
# <class 'tuple'>

# %% [markdown]
# ####Tuple Items - Data Types
# Tuple items can be of any data type:

# %%
tuple1 = ("clever", "studies", "classes", "are", "going on")
tuple2 = (1,2,3,4,5,6,7,8,9)
tuple3 = (True,False,False)
print(tuple1)
print(tuple2)
print(tuple3)
# Out:
# ('clever', 'studies', 'classes', 'are', 'going on')
# (1, 2, 3, 4, 5, 6, 7, 8, 9)
# (True, False, False)

# %%
#A tuple can contain different data types:
tuple1 = ("clever", "studies", "classes", "are", "going on",1,2,3,3,True,False,True)
print(tuple1)
# Out:
# ('clever', 'studies', 'classes', 'are', 'going on', 1, 2, 3, 3, True, False, True)

# %% [markdown]
# ####The tuple() Constructor
# It is also possible to use the tuple() constructor to make a tuple.

# %%
tuple1 = tuple(("clever", "studies", "classes", "are", "going on"))
print(tuple1)
# Out:
# ('clever', 'studies', 'classes', 'are', 'going on')

# %% [markdown]
# ####Access Tuple Items
# You can access tuple items by referring to the index number, inside square brackets:

# %%
tuple1 = ("clever", "studies", "classes", "are", "going on")
print(tuple1[1])
# Out:
# studies

# %%
tuple1 = ("clever", "studies", "classes", "are", "going on")
print(tuple1[-1])
# Out:
# going on

# %% [markdown]
# ####Range of Indexes
# You can specify a range of indexes by specifying where to start and where to end the range.
#
# When specifying a range, the return value will be a new tuple with the specified items.

# %%
tuple1 = ("clever", "studies", "classes", "are", "going on")
print(tuple1[2:5])
# Out:
# ('classes', 'are', 'going on')

# %%
tuple1 = ("clever", "studies", "classes", "are", "going on")
print(tuple1[:4])
# Out:
# ('clever', 'studies', 'classes', 'are')

# %%
tuple1 = ("clever", "studies", "classes", "are", "going on")
print(tuple1[2:])
# Out:
# ('classes', 'are', 'going on')

# %%
tuple1 = ("clever", "studies", "classes", "are", "going on")
print(tuple1[-4:-1])
# Out:
# ('studies', 'classes', 'are')

# %% [markdown]
# ####Check if Item Exists
# To determine if a specified item is present in a tuple use the in keyword:

# %%
tuple1 = ("clever", "studies", "classes", "are", "going on")
if "are" in tuple1:
    print("Yes,are is in the tuple1")
# Out:
# Yes,are is in the tuple1

# %% [markdown]
# ####Change Tuple Values
# Once a tuple is created, you cannot change its values. Tuples are unchangeable, or immutable as it also is called.
#
# But there is a workaround. You can convert the tuple into a list, change the list, and convert the list back into a tuple.

# %%
x = ("clever", "studies", "classes")
y = list(x)
y[1] = "classes"
x = tuple(y)
print(x)
# Out:
# ('clever', 'classes', 'classes')

# %%
x = ("clever", "studies", "classes")
y = list(x)
y.append("are going on")
x = tuple(y)
print(x)
# Out:
# ('clever', 'studies', 'classes', 'are going on')

# %%
x = ("clever", "studies", "classes")
y = ("are going on",)
x += y
print(x)
# Out:
# ('clever', 'studies', 'classes', 'are going on')

# %% [markdown]
# ####Remove Items
# Tuples are unchangeable, so you cannot remove items from it, but you can use the same workaround as we used for changing and adding tuple items:

# %%
x = ("clever", "studies", "classes")
y = list(x)
y.remove("classes")
x = tuple(y)
print(x)
# Out:
# ('clever', 'studies')

# %%
x = ("clever", "studies", "classes")
del x
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-547929580203182>, line 3
#       1 x = ("clever", "studies", "classes")
#       2 del x
# ----> 3 print(x)
#
# NameError: name 'x' is not defined

# %% [markdown]
# ####Unpacking a Tuple
# When we create a tuple, we normally assign values to it. This is called "packing" a tuple:
# But, in Python, we are also allowed to extract the values back into variables. This is called "unpacking":

# %%
x = ("clever", "studies", "classes")
(are, going,on) = x
print(are)
print(going)
print(on)
# Out:
# clever
# studies
# classes

# %%
x = ("clever", "studies", "classes", "are", "going on")
(are, going,*on) = x
print(are)
print(going)
print(on)
# Out:
# clever
# studies
# ['classes', 'are', 'going on']

# %%
x = ("clever", "studies", "classes", "are", "going on")
(are,*going,on) = x
print(are)
print(going)
print(on)
# Out:
# clever
# ['studies', 'classes', 'are']
# going on

# %% [markdown]
# ####Join Two Tuples
# To join two or more tuples you can use the + operator:

# %%
x = ("clever", "studies", "classes")
y = ("are","going","on")
z = x+y
print(z)
# Out:
# ('clever', 'studies', 'classes', 'are', 'going', 'on')

# %%
#If you want to multiply the content of a tuple a given number of times, you can use the * operator:
x = ("clever", "studies", "classes")
y =  x*2
print(y)
# Out:
# ('clever', 'studies', 'classes', 'clever', 'studies', 'classes')

# %% [markdown]
# ####Python Tuple count() Method
# The count() method returns the number of times a specified value appears in the tuple.

# %%
x = (1,2,3,2,4,6,2,4,6,7,8,9)
y = x.count(2)
print(y)
# Out:
# 3

# %%
x = (1,2,3,2,4,6,2,4,6,7,8,9)
y = x.index(6)
print(y)
# Out:
# 5
