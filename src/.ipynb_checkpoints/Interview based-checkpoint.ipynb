# %%
#Generators are one of Python’s most memory-efficient tools — but do you really know how they behave after iteration?
x = (i for i in range(3))
print(list(x)) 
print(list(x))
#A generator is an iterator that yields items one at a time, only when requested — 
#making it great for handling large data streams without consuming memory like lists
# Out:
# [0, 1, 2]
# []
