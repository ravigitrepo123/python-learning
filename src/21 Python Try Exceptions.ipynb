# %% [markdown]
# ####Exception Handling
# When an error occurs, or exception as we call it, Python will normally stop and generate an error message.
#
# These exceptions can be handled using the try statement:

# %% [markdown]
# #####The try block lets you test a block of code for errors.
#
# #####The except block lets you handle the error.
#
# #####The else block lets you execute code when there is no error.
#
# #####The finally block lets you execute code, regardless of the result of the try- and except blocks.

# %%
try:
    print(x)
except:
    print("x is not defined/an exception occured")
#The try block will generate an error, because x is not defined:
# Out:
# x is not defined/an exception occured

# %%
#Since the try block raises an error, the except block will be executed.

#Without the try block, the program will crash and raise an error:
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 #Since the try block raises an error, the except block will be executed.
#       2
#       3 #Without the try block, the program will crash and raise an error:
# ----> 4 print(x)
#
# NameError: name 'x' is not defined

# %% [markdown]
# ####Many Exceptions
# You can define as many exception blocks as you want, e.g. if you want to execute a special block of code for a special kind of error:

# %%
#Print one message if the try block raises a NameError and another for other errors:
try:
  print(x)
except NameError:
  print("Variable x is not defined")
except:
  print("Something else went wrong")
# Out:
# Variable x is not defined

# %% [markdown]
# ####Else
# You can use the else keyword to define a block of code to be executed if no errors were raised:

# %%
try:
  print("Clever studies classes are going on")
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
#The try block does not raise any errors, so the else block is executed:
# Out:
# Clever studies classes are going on
# Nothing went wrong

# %% [markdown]
# ####Finally
# The finally block, if specified, will be executed regardless if the try block raises an error or not.

# %%
try:
  print(x)
except:
  print("Something went wrong")
finally:
  print("The 'try except' is finished")
#The finally block gets executed no matter if the try block raises any error or not:
# Out:
# Something went wrong
# The 'try except' is finished

# %% [markdown]
# ####Raise an exception
# As a Python developer you can choose to throw an exception if a condition occurs.
#
# To throw (or raise) an exception, use the raise keyword.

# %%
x = -3
if x < 0:
    raise Exception("no numbers below zero")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 x = -3
#       2 if x < 0:
# ----> 3     raise Exception("no numbers below zero")
#
# Exception: no numbers below zero

# %%
#The raise keyword is used to raise an exception.
#You can define what kind of error to raise, and the text to print to the user.
x = "clever studies classes are going on:"
if not type(x) is int:
    raise TypeError("only integers are allowed")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       3 x = "clever studies classes are going on:"
#       4 if not type(x) is int:
# ----> 5     raise TypeError("only integers are allowed")
#
# TypeError: only integers are allowed
