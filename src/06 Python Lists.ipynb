# %% [markdown]
# ####List
# Lists are used to store multiple items in a single variable.
#
# Lists are one of 4 built-in data types in Python used to store collections of data

# %% [markdown]
# "Lists are Indexed, Mutable, and Allow Duplicate Values"\
# "Tuples are Indexed, Immutable, and Allow Duplicate Values"\
# "sets are Unindexed, Mutable, and Do Not Allow Duplicate Values"\
# "dictionaries are Indexed by keys, Only values are Mutable, and Do Not Allow Duplicate key-value pairs"

# %%
thislist = ["clever", "studies", "classes"]
print(thislist)
# Out:
# ['clever', 'studies', 'classes']

# %% [markdown]
# ####List Items
# List items are ordered, changeable, and allow duplicate values.
#
# List items are indexed, the first item has index [0], the second item has index [1] etc.

# %% [markdown]
# ####Ordered
# When we say that lists are ordered, it means that the items have a defined order, and that order will not change.
#
# If you add new items to a list, the new items will be placed at the end of the list.

# %% [markdown]
# ####Changeable
# The list is changeable, meaning that we can change, add, and remove items in a list after it has been created.

# %% [markdown]
# ####Allow Duplicates
# Since lists are indexed, lists can have items with the same value:

# %%
list1 = ['clever', 'studies', 'classes','clever']
x = list1
print(x)
# Out:
# ['clever', 'studies', 'classes', 'clever']

# %% [markdown]
# ####List Length
# To determine how many items a list has, use the len() function:

# %%
list1 = ['clever', 'studies', 'classes','clever']
x = list1
print(len(x))
# Out:
# 4

# %% [markdown]
# ####List Items - Data Types
# List items can be of any data type

# %%
list1 = ["clever", "studies", "classes"]
list2 = [1, 5, 7, 9, 3]
list3 = [True, False, False]
print(list1)
print(list2)
print(list3)
# Out:
# ['clever', 'studies', 'classes']
# [1, 5, 7, 9, 3]
# [True, False, False]

# %%
#A list can contain different data types:
list1 = ["clever", 34, True, 40, "studies"]
print(list1)
# Out:
# ['clever', 34, True, 40, 'studies']

# %% [markdown]
# ####type()
# From Python's perspective, lists are defined as objects with the data type 'list':

# %%
list1 = ["clever", "studies", "classes"]
print(type(list1))
# Out:
# <class 'list'>

# %% [markdown]
# ####The list() Constructor
# It is also possible to use the list() constructor when creating a new list.

# %%
list1 = list(("clever", "studies", "classes"))
print(list1)
# Out:
# ['clever', 'studies', 'classes']

# %% [markdown]
# ####Python - Access List Items
# List items are indexed and you can access them by referring to the index number:

# %%
list1 = ["clever", "studies", "classes"]
print(list1[1])
#The first item has index 0.
# Out:
# studies

# %% [markdown]
# ####Negative Indexing
# Negative indexing means start from the end
#
# -1 refers to the last item, -2 refers to the second last item etc.

# %%
list1 = ["clever", "studies", "classes"]
print(list1[-1])
# Out:
# classes

# %% [markdown]
# ####Range of Indexes
# You can specify a range of indexes by specifying where to start and where to end the range.
#
# When specifying a range, the return value will be a new list with the specified items.

# %%
#Return the third, fourth, and fifth item:
list1 = ["clever", "studies", "classes","are","going","on"]
print(list1[2:5])
# The search will start at index 2 (included) and end at index 5 (not included).
# Out:
# ['classes', 'are', 'going']

# %%
#This example returns the items from the beginning to, but NOT including
list1 = ["clever", "studies", "classes","are","going","on"]
print(list1[:3])
# Out:
# ['clever', 'studies', 'classes']

# %%
#By leaving out the end value, the range will go on to the end of the list:
list1 = ["clever", "studies", "classes","are","going","on"]
print(list1[2:])
# Out:
# ['classes', 'are', 'going', 'on']

# %% [markdown]
# ###Range of Negative Indexes
# Specify negative indexes if you want to start the search from the end of the list:

# %%
list1 = ["clever", "studies", "classes","are","going","on"]
print(list1[-5:-2])
# Out:
# ['studies', 'classes', 'are']

# %% [markdown]
# ###Check if Item Exists
# To determine if a specified item is present in a list use the in keyword

# %%
list1 = ["clever", "studies", "classes","are","going","on"]
if "going" in thislist:
  print("Yes, 'going' is in the list")

# %% [markdown]
# ####Python - Change List Items
# To change the value of a specific item, refer to the index number:

# %%
list1 = ["clever", "studies", "classes","are","going","on"]
list1[1] = "course"
print(list1)
# Out:
# ['clever', 'course', 'classes', 'are', 'going', 'on']

# %% [markdown]
# ####Change a Range of Item Values
# To change the value of items within a specific range, define a list with the new values, and refer to the range of index numbers where you want to insert the new values:

# %%
list1 = ["clever", "studies", "classes","are","going","on"]
list1[1:3] = ["course","study"]
print(list1)
# Out:
# ['clever', 'course', 'study', 'are', 'going', 'on']

# %% [markdown]
# ##
# If you insert more items than you replace, the new items will be inserted where you specified, and the remaining items will move accordingly:

# %%
list1 = ["clever","studies","classes"]
list1[1:2]=("are","good")
print(list1)
#The length of the list will change when the number of items inserted does not match the number of items replaced.
# Out:
# ['clever', 'are', 'good', 'classes']

# %% [markdown]
# ###
# If you insert less items than you replace, the new items will be inserted where you specified, and the remaining items will move accordingly:

# %%
list1 = ["clever","studies","classes"]
list1[1:3]=("are")
print(list1)
# Out:
# ['clever', 'a', 'r', 'e']

# %%
list1 = ["clever","studies","classes","were","good","hell0"]
list1[2:4]=("are")
print(list1)
# Out:
# ['clever', 'studies', 'a', 'r', 'e', 'good', 'hell0']

# %% [markdown]
# ####Python List insert() Method
# The insert() method inserts the specified value at the specified position.

# %%
list1 = ['clever', 'studies']
x=list1.insert(2, "classes")
print(x)
# Out:
# None

# %% [markdown]
# ####Python List append() Method
# The append() method appends an element to the end of the list.

# %%
list1 = ['clever', 'studies', 'classes']
list1.append("are good")
print(list1)
# Out:
# ['clever', 'studies', 'classes', 'are good']

# %%
a = ["clever", "studies", "classes"]
b = ["are", "going", "on"]
a.append(b)

# %% [markdown]
# ####Python List extend() Method
#
# The extend() method adds the specified list elements (or any iterable) to the end of the current list.

# %%
list1 = ['clever', 'studies']
list2 = ['classes', 'are', 'good']
list1.extend(list2)
print(list1)
# Out:
# ['clever', 'studies', 'classes', 'are', 'good']

# %%
list1 = ['clever', 'studies', 'classes']
points = (1, 4, 5, 9)
list1.extend(points)
print(list1)
# Out:
# ['clever', 'studies', 'classes', 1, 4, 5, 9]

# %% [markdown]
# ####Python List remove() Method
# The remove() method removes the first occurrence of the element with the specified value.

# %%
list1 = ['clever', 'studies', 'classes']
x = list1.remove("classes")
print(x)
# Out:
# None

# %% [markdown]
# ####Python List pop() Method
# The pop() method removes the element at the specified position.

# %%
list1 = ['clever', 'studies', 'classes']
x = list1.pop(1)
print(x)
# Out:
# studies

# %%
list1 = ["clever", "studies", "classes"]
del list1[0]
print(list1)
# Out:
# ['studies', 'classes']

# %% [markdown]
# ####Python List clear() Method
# The clear() method removes all the elements from a list.

# %%
list1 = ['clever', 'studies', 'classes']
list1.clear()
print(list1)
# Out:
# []

# %% [markdown]
# ####Python List copy() Method
# The copy() method returns a copy of the specified list.

# %%
list1 = ['clever', 'studies', 'classes']
x = list1.copy()
print(x)
# Out:
# ['clever', 'studies', 'classes']

# %% [markdown]
# ####Python List count() Method
# The count() method returns the number of elements with the specified value.

# %%
list1 = ['clever', 'studies', 'classes']
x = list1.count("clever")
print(x)
# Out:
# 1

# %%
list1 = ['clever', 'clever', 'studies','classes']
x = list1.count("clever")
print(x)
# Out:
# 2

# %% [markdown]
# ####Python List index() Method
# The index() method returns the position at the first occurrence of the specified value

# %%
list1 = ['clever', 'studies', 'classes']
x = list1.index("classes")
print(x)
# Out:
# 2

# %%
points = (1, 4, 5, 9,4,5,8)
x = points.index(4)
print(x)
# The index() method only returns the first occurrence of the value.
# Out:
# 1

# %% [markdown]
# ####Python List reverse() Method
# The reverse() method reverses the sorting order of the elements

# %%
list1 = ['clever', 'studies', 'are','going','on']
list1.reverse()
print(list1)
# Out:
# ['on', 'going', 'are', 'studies', 'clever']

# %% [markdown]
# ####Python List sort() Method
# The sort() method sorts the list ascending by default.

# %%
list1 = ['clever','are', 'studies', 'going']
list1.sort()
print(list1)
# Out:
# ['are', 'clever', 'going', 'studies']

# %%
list1 = ['clever', 'studies', 'classes']
list1.sort(reverse = True)
print(list1)
# Out:
# ['studies', 'clever', 'classes']

# %%
#Sort the list descending:
thislist = [100, 50, 65, 82, 23]
thislist.sort(reverse = True)
print(thislist)

# %% [markdown]
# ###Customize Sort Function
# You can also customize your own function by using the keyword argument key = function.
# The function will return a number that will be used to sort the list (the lowest number first):

# %%
#Sort the list based on how close the number is to 50:
def myfunc(n):
  return abs(n - 50)
thislist = [100, 50, 65, 82, 23]
thislist.sort(key = myfunc)
print(thislist)

# %% [markdown]
# ###Case Insensitive Sort
# By default the sort() method is case sensitive, resulting in all capital letters being sorted before lower case letters:

# %%
#Case sensitive sorting can give an unexpected result:
thislist = ["clever", "Orange", "Kiwi", "cherry"]
thislist.sort()
print(thislist)

# %%
#Luckily we can use built-in functions as key functions when sorting a list.
#So if you want a case-insensitive sort function, use str.lower as a key function.
#Perform a case-insensitive sort of the list:
thislist = ["Clever", "Studies", "Classes", "Are Going"]
thislist.sort(key = str.lower)
print(thislist)

# %% [markdown]
# ###Reverse Order
# - What if you want to reverse the order of a list, regardless of the alphabet?
# - The reverse() method reverses the current sorting order of the elements.
# - Reverse the order of the list items:

# %%
thislist = ["clever", "studies", "classes", "are going on"]
thislist.reverse()
print(thislist)

# %% [markdown]
# ###Copy List
# You cannot copy a list simply by typing list2 = list1, because: list2 will only be a reference to list1, and changes made in list1 will automatically also be made in list2.

# %% [markdown]
# ####Use the copy() method
# You can use the built-in List method copy() to copy a list

# %%
#Make a copy of a list with the copy() method:
thislist = ["clever", "studies", "classes"]
mylist = thislist.copy()
print(mylist)

# %% [markdown]
# ###Use the list() method
# Another way to make a copy is to use the built-in method list().

# %%
#Make a copy of a list with the list() method:
thislist = ["apple", "banana", "cherry"]
mylist = list(thislist)
print(mylist)

# %% [markdown]
# ###Use the slice Operator
# You can also make a copy of a list by using the : (slice) operator.

# %%
#Make a copy of a list with the : operator:
thislist = ["apple", "banana", "cherry"]
mylist = thislist[:]
print(mylist)

# %% [markdown]
# ###Python - Join Lists
# - Join Two Lists
# - There are several ways to join, or concatenate, two or more lists in Python.
# - One of the easiest ways are by using the + operator.

# %%
#Join two list:
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]
list3 = list1 + list2
print(list3)

# %%
#Another way to join two lists is by appending all the items from list2 into list1, one by one:
#Append list2 into list1:
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]
for x in list2:
  list1.append(x)
print(list1)

# %%
#Or you can use the extend() method, where the purpose is to add elements from one list to another list:
#Use the extend() method to add list2 at the end of list1:
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]
list1.extend(list2)
print(list1)

# %% [markdown]
# Sort List Alphanumerically
# List objects have a sort() method that will sort the list alphanumerically, ascending, by default:
