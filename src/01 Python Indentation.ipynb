# %% [markdown]
# ##Python Indentation:

# %% [markdown]
# In Python, indentation is critical because it defines the structure of the code. Unlike many other programming languages that use braces {} to define blocks of code, Python uses indentation (spaces or tabs) to group statements.
#
# ####Why Indentation is Important:
# Defines Code Blocks: Indentation tells Python which code belongs to which block (loops, conditionals, functions, etc.).
# Improves Readability: Proper indentation makes the code easier to read and understand.
#
# #### Rules of Indentation:
# Consistency: Always use the same number of spaces or tabs for indentation. The standard is 4 spaces per indentation level.
# No Mixing Tabs and Spaces: Stick to one method of indentation. Mixing spaces and tabs will result in an error.

# %% [markdown]
# #####Example 1: If-Else Statement

# %%
x = 10

if x > 5:
    print("x is greater than 5")  # This code is inside the 'if' block
else:
    print("x is not greater than 5")  # This code is inside the 'else' block

# %% [markdown]
# #####In this example:
#
# The print() statements are indented by 4 spaces.
#
# If the indentation were incorrect (e.g., missing or inconsistent), Python would raise an IndentationError.

# %% [markdown]
# #####Example 2: For Loop

# %%
for i in range(5):
    print(i)  # This code is inside the loop block

# %% [markdown]
# ***Here:*** The print(i) is indented to indicate that it belongs to the for loop.

# %% [markdown]
# ##### Example 3: Function Definition

# %%
def greet(name):
    print("Hello, " + name)  # Indented inside the function

greet("Alice")

# %% [markdown]
# The print() statement is indented to show that it is part of the greet function.

# %% [markdown]
# #####Example 4: Incorrect Indentation

# %%
x = 10

if x > 5:
print("x is greater than 5")  # Indentation error

# %% [markdown]
# This will raise an IndentationError because the print() statement is not indented correctly.
#
# ***Tip:***
# Use your text editor or IDE's "Auto-Indent" feature to avoid errors and maintain consistent indentation.
#
# ***Summary:***
#
# Indentation defines code blocks in Python.
#
# Always use 4 spaces for indentation (avoid tabs).
#
# Incorrect or inconsistent indentation will result in errors.
